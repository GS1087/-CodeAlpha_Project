# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[["Name","Sex","Ticket","Cabin","Embarked"]]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
a=df[df["Sex"] == "male"]
a[a["Survived"] == 1]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
a=df[df["Sex"] == "female"]
a[a["Survived"] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #  Creates a bar chart for survival rates based on a specified group.
#
# ## Args:
# ###     df (pandas.DataFrame): The data containing survival information.
# ###       group_by (str): The column name for grouping (e.g., "Sex").
# ###       title (str): The title for the bar chart.
# ### colormap (str, optional): The colormap to use for visualization. Defaults to 'RdGy'.

# %%
def plot_survival_rates(df, group_by, title, colormap='RdGy'):

  survived_counts = df.groupby(group_by)['Survived'].value_counts(normalize=True).unstack()
  survived_counts.plot(kind='bar', colormap=colormap)
  plt.xlabel(group_by)
  plt.ylabel('Survival Rate')
  plt.title(title)
  plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
  plt.tight_layout()
  plt.show()

# Load data (assuming "titanic.csv")
df = pd.read_csv('titanic.csv')

# Plot survival rates for males
plot_survival_rates(df[df['Sex'] == 'male'], 'Sex', 'Survival Rates for Males on the Titanic')

# Plot survival rates for females (can be done similarly)
plot_survival_rates(df[df['Sex'] == 'female'], 'Sex', 'Survival Rates for Females on the Titanic')

# %%
survival_rates = df.groupby(['Sex', 'Survived']).size().unstack(fill_value=0)
survival_rates.plot(kind='bar', colormap='seismic')  # Adjust colormap as desired

plt.xlabel('Sex')
plt.ylabel('Survival Rate')
plt.title('Survival Rates for Males and Females on the Titanic')
plt.xticks(rotation=0)  # Rotate x-axis labels
plt.legend(title='Survived')  # Adjust legend title
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in a CSV file named "titanic.csv"
df = pd.read_csv("titanic.csv")

# Filter data for males
males = df[df["Sex"] == "male"]

# Count survivors and non-survivors for males
male_survived_count = males[males["Survived"] == 1].shape[0]
male_not_survived_count = males[males["Survived"] == 0].shape[0]

# Data for the pie chart (male survival)
pie_labels = ["Survived", "Not Survived"]
pie_values = [male_survived_count, male_not_survived_count]

# Create the pie chart for males
plt.figure(figsize=(6, 6))  # Adjust figure size as needed
plt.pie(pie_values, labels=pie_labels, autopct="%1.1f%%", startangle=140)  # Customize options as desired
plt.title("Survival Rates for Males on the Titanic")
plt.axis("equal")  # Equal aspect ratio for a circular pie chart
plt.show()

# %%
# Filter data for females (similar to males)
females = df[df["Sex"] == "female"]

# Count survivors and non-survivors for females
female_survived_count = females[females["Survived"] == 1].shape[0]
female_not_survived_count = females[females["Survived"] == 0].shape[0]

# Data for the pie chart (female survival)
pie_labels = ["Survived", "Not Survived"]
pie_values = [female_survived_count, female_not_survived_count]

# Create the pie chart for females
plt.figure(figsize=(6, 6))  # Adjust figure size as needed
plt.pie(pie_values, labels=pie_labels, autopct="%1.1f%%", startangle=140)  # Customize options as desired
plt.title("Survival Rates for Females on the Titanic")
plt.axis("equal")  # Equal aspect ratio for a circular pie chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in a CSV file named "titanic.csv"
df = pd.read_csv("titanic.csv")

# Filter data for clarity (assuming Age and Survived are columns)
df_filtered = df[['Age', 'Survived']]

# Create the scatter plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
plt.scatter(df_filtered['Age'], df_filtered['Survived'], alpha=0.5, c='blue')  # Adjust alpha for transparency

# Label the axes
plt.xlabel("Age")
plt.ylabel("Survived (1) / Not Survived (0)")
plt.title("Age vs. Survival on the Titanic")

# Add a grid for better readability
plt.grid(True)

# Display the scatter plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("titanic.csv")

# Explore survival rates by Pclass (socioeconomic status)
pclass_survival_rates = df.groupby("Pclass")["Survived"].mean()
print("Survival Rates by Pclass (Higher = Wealthier):")
print(pclass_survival_rates)

# Explore survival rates by Age (consider grouping into age ranges)
age_groups = [0, 10, 20, 30, 40, 50, 60, 70, 80]
age_survival_rates = df.groupby(pd.cut(df["Age"], age_groups))["Survived"].mean()
print("\nSurvival Rates by Age Groups:")
print(age_survival_rates)

# Explore survival rates by Gender
gender_survival_rates = df.groupby("Sex")["Survived"].mean()
print("\nSurvival Rates by Gender:")
print(gender_survival_rates)

# Optional: Create visualizations (bar charts, histograms) using matplotlib

# Remember, these are just trends, not guarantees of survival for any individual.
# Out:
# Survival Rates by Pclass (Higher = Wealthier):
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64
#
# Survival Rates by Age Groups:
# Age
# (0, 10]     0.593750
# (10, 20]    0.382609
# (20, 30]    0.365217
# (30, 40]    0.445161
# (40, 50]    0.383721
# (50, 60]    0.404762
# (60, 70]    0.235294
# (70, 80]    0.200000
# Name: Survived, dtype: float64
#
# Survival Rates by Gender:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in a CSV file named "titanic.csv"
df = pd.read_csv("titanic.csv")

# Function to create a pie chart with informative title
def create_pie_chart(data_series, title):
  plt.figure(figsize=(6, 6))  # Adjust figure size as needed
  plt.pie(data_series.values, labels=data_series.index, autopct="%1.1f%%", startangle=140)
  plt.title(title)
  plt.axis("equal")  # Equal aspect ratio for a circular pie chart
  plt.show()

# Survival Rates by Pclass
pclass_survival_rates = df.groupby("Pclass")["Survived"].mean()
create_pie_chart(pclass_survival_rates, "Survival Rates by Pclass (Higher = Wealthier)")

# Survival Rates by Age Groups (consider adjusting age ranges)
age_groups = [0, 10, 20, 30, 40, 50, 60, 70, 80]
age_survival_rates = df.groupby(pd.cut(df["Age"], age_groups))["Survived"].mean()
create_pie_chart(age_survival_rates, "Survival Rates by Age Groups")

# Survival Rates by Gender
gender_survival_rates = df.groupby("Sex")["Survived"].mean()
create_pie_chart(gender_survival_rates, "Survival Rates by Gender")

# Remember, these are trends, not guarantees, and the dataset might have limitations.

# %%
def plot_survival_rates(df, group_by, title, colormap='RdGy'):
  """
  Creates a bar chart for survival rates based on a specified group.

  Args:
      df (pandas.DataFrame): The data containing survival information.
      group_by (str): The column name for grouping (e.g., "Sex").
      title (str): The title for the bar chart.
      colormap (str, optional): The colormap to use for visualization. Defaults to 'RdGy'.
  """
  survived_counts = df.groupby(group_by)['Survived'].value_counts(normalize=True).unstack()
  survived_counts.plot(kind='bar', colormap=colormap)
  plt.xlabel(group_by)
  plt.ylabel('Survival Rate')
  plt.title(title)
  plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
  plt.tight_layout()
  plt.show()

# Load data (assuming "titanic.csv")
df = pd.read_csv('titanic.csv')

# Plot survival rates for males
plot_survival_rates(df[df['Sex'] == 'male'], 'Sex', 'Survival Rates for Males on the Titanic')

# Plot survival rates for females (can be done similarly)
plot_survival_rates(df[df['Sex'] == 'female'], 'Sex', 'Survival Rates for Females on the Titanic')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your data is in a CSV file named "titanic.csv"
df = pd.read_csv("titanic.csv")

survival_rates = df.groupby(['Sex', 'Survived']).size().unstack(fill_value=0)
survival_rates.plot(kind='bar', colormap='seismic')  # Adjust colormap as desired

plt.xlabel('Sex')
plt.ylabel('Survival Rate')
plt.title('Survival Rates for Males and Females on the Titanic')
plt.xticks(rotation=0)  # Rotate x-axis labels
plt.legend(title='Survived')  # Adjust legend title
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data (assuming "titanic.csv")
df = pd.read_csv("titanic.csv")

# Group by Sex, calculate survival rate, and plot pie chart
df.groupby('Sex')['Survived'].value_counts().unstack().plot(kind='pie', autopct='%1.1f%%', startangle=140, figsize=(6, 6), title='Survival Rates by Sex (Males)')
plt.axis('equal')  # Equal aspect ratio for a circular pie chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 8
#       5 df = pd.read_csv("titanic.csv")
#       7 # Group by Sex, calculate survival rate, and plot pie chart
# ----> 8 df.groupby('Sex')['Survived'].value_counts().unstack().plot(kind='pie', autopct='%1.1f%%', startangle=140, figsize=(6, 6), title='Survival Rates by Sex (Males)')
#       9 plt.axis('equal')  # Equal aspect ratio for a circular pie chart
#      10 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:926, in PlotAccessor.__call__(self, *args, **kwargs)
#     924 if isinstance(data, ABCDataFrame):
#     925     if y is None and kwargs.get("subplots") is False:
# --> 926         raise ValueError(
#     927             f"{kind} requires either y column or 'subplots=True'"
#     928         )
#     929     if y is not None:
# ...
